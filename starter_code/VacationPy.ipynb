# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  new norfolk -42.7826  147.0587     10.72        63          99
# 1        1      fortuna  40.5982 -124.1573      9.40        93          75
# 2        2   georgetown   5.4112  100.3354     27.91        86          40
# 3        3     vanavara  60.3400  102.2797    -11.59        86         100
# 4        4       atuona  -9.8000 -139.0333     24.91        78          82
#
#    Wind Speed Country        Date
# 0        0.45      AU  1670264953
# 1        5.66      US  1670264954
# 2        0.51      MY  1670264694
# 3        6.38      RU  1670264696
# 4        7.36      PF  1670264959

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
"Lng","Lat",
geo = True,tiles = "OSM",frame_width = 600, frame_height = 450, size='Humidity', color = "City")

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
my_vacay = city_data_df.loc[(city_data_df['Max Temp']>15) & 
                            (city_data_df['Max Temp']<25) &
                            (city_data_df['Humidity'] > 40) &
                            (city_data_df['Humidity'] < 59) &
                            (city_data_df['Cloudiness'] < 70), :]

# Drop any rows with null values
my_vacay.dropna()

# Display sample data
my_vacay
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 56        56        barela  23.1000   80.0500     15.72        54           0
# 155      155       emerald -23.5333  148.1667     22.43        58           1
# 182      182          esna  25.2934   32.5540     20.01        48           0
# 212      212  constitucion -35.3333  -72.4167     19.89        57           7
# 216      216        gerash  27.6652   54.1371     16.08        48          18
# 317      317        dwarka  22.2394   68.9678     23.49        43           0
# 349      349       ishurdi  24.1333   89.0833     18.68        53           0
# 372      372         tahta  26.7693   31.5021     17.84        48           0
# 420      420         aswan  24.0934   32.9070     20.61        45           0
# 422      422        khetia  21.6667   74.5833     24.23        50           6
# 449      449       winslow  35.0242 -110.6974     15.10        47          40
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = my_vacay[['City','Country', 'Lat','Lng','Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = " "

# Display sample data
hotel_df
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_11228\231492471.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = " "
#              City Country      Lat       Lng  Humidity Hotel Name
# 56         barela      IN  23.1000   80.0500        54
# 155       emerald      AU -23.5333  148.1667        58
# 182          esna      EG  25.2934   32.5540        48
# 212  constitucion      CL -35.3333  -72.4167        57
# 216        gerash      IR  27.6652   54.1371        48
# 317        dwarka      IN  22.2394   68.9678        43
# 349       ishurdi      BD  24.1333   89.0833        53
# 372         tahta      EG  26.7693   31.5021        48
# 420         aswan      EG  24.0934   32.9070        45
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories":"accommodation.hotel","apiKey":geoapify_key,
    "limit":1}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = row["Lat"]
    Lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filters"]= f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
           hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
           hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# barela - nearest hotel: Satya Ashoka
# emerald - nearest hotel: Emerald Central Hotel
# esna - nearest hotel: Hotel Maritim Jolie Ville
# constitucion - nearest hotel: Hostal Alameda
# gerash - nearest hotel: هتل آبشار
# dwarka - nearest hotel: The Dwarika Hotel
# ishurdi - nearest hotel: Inspection Banglo,Pakshi,Pabna,RHD পরিদর্শন বাংলো,পাকশী,সওজ
# tahta - nearest hotel: Al Safa Hotel
# aswan - nearest hotel: Yaseen hotel
# khetia - nearest hotel: No hotel found
# winslow - nearest hotel: La Posada Hotel
# kifri - nearest hotel: Manor
# abu kamal - nearest hotel: No hotel found
# chicama - nearest hotel: Hotel Wasi
# siva - nearest hotel: فندق الكيلانى
# capaci - nearest hotel: Saracen Sands
# zacualtipan - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity  \
# 56         barela      IN  23.1000   80.0500        54
# 155       emerald      AU -23.5333  148.1667        58
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_hotels = hotel_df.hvplot.points(
"Lng","Lat",
geo = True,tiles = "OSM",frame_width = 600, frame_height = 450, size='Humidity', color = "City", hover_cols=["Hotel Name", "Country"])


# Display the map
map_hotels
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
